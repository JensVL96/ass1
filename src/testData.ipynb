# %%
import matplotlib.pyplot as plt

# Data for the first graph
reducer_counts_1 = [2, 2, 2, 2, 4, 4, 4, 4, 8, 8, 8, 8, 16, 16, 16, 16]
mapper_counts_1 = [2, 4, 8, 16, 2, 4, 8, 16, 2, 4, 8, 16, 2, 4, 8, 16]

# Large data set
times_1 = [
    (71.50268244743347 + 71.36451172828674 + 71.67293334007263) / 3,
    (69.83384203910828 + 69.24604487419128 + 69.85753011703491) / 3,
    (70.15922832489014 + 68.7616982460022 + 68.85229420661926) / 3,
    (71.56477308273315 + 69.89269232749939 + 73.6531434059143) / 3,
    (67.62529802322388 + 60.633914947509766 + 61.6978063583374) / 3,
    (63.91146731376648 + 58.80120229721069 + 63.25221347808838) / 3,
    (60.930219888687134 + 59.10850286483765 + 59.906330823898315) / 3,
    (67.33778190612793 + 60.11123871803284 + 60.69636511802673) / 3,
    (57.470606327056885 + 56.53031539916992 + 58.03199076652527) / 3,
    (56.27682614326477 + 54.486366271972656 + 55.64425039291382) / 3,
    (56.10840344429016 + 58.331708669662476 + 59.02232885360718) / 3,
    (55.99714469909668 + 57.586487770080566 + 55.46504616737366) / 3,
    (55.72042202949524 + 59.431453704833984 + 55.596710205078125) / 3,
    (54.927385091781616 + 54.46436882019043 + 53.8859281539917) / 3,
    (52.56553030014038 + 55.04127359390259 + 54.87207865715027) / 3,
    (55.122700452804565 + 55.568750619888306 + 53.315985679626465) / 3
]

# Organize data by reducer count for the first graph
reducer_data_1 = {}
for i in range(len(mapper_counts_1)):
    reducer = reducer_counts_1[i]
    if reducer not in reducer_data_1:
        reducer_data_1[reducer] = {'mappers': [], 'times': []}
    reducer_data_1[reducer]['mappers'].append(mapper_counts_1[i])
    reducer_data_1[reducer]['times'].append(times_1[i])  # Use times_1 directly

# Plot the first graph
plt.figure(figsize=(10, 6))
colors = ['b', 'g', 'r', 'c']  # Different colors for each reducer count
for i, (reducer, data) in enumerate(reducer_data_1.items()):
    plt.plot(data['mappers'], data['times'], marker='o', color=colors[i], label=f'Reducers: {reducer}')

plt.xlabel('Mapper Count')
plt.ylabel('Average Time (seconds)')
plt.title('Average Time vs Mapper Count for Different Reducer Counts (Graph 1)')
plt.legend()
plt.grid(True)
plt.xticks([2, 4, 8, 16])  # Ensure x-ticks match mapper counts
plt.show()

# %%
# Data for the second graph
reducer_counts_2 = [2, 2, 2, 2, 4, 4, 4, 4, 8, 8, 8, 8, 16, 16, 16, 16]
mapper_counts_2 = [2, 4, 8, 16, 2, 4, 8, 16, 2, 4, 8, 16, 2, 4, 8, 16]

# Small data set
times_2 = [
    (18.66226100921631 + 17.778854370117188 + 17.728405237197876) / 3,
    (17.793211698532104 + 17.47324252128601 + 17.834439277648926) / 3,
    (17.90614080429077 + 17.767274618148804 + 17.452941179275513) / 3,
    (18.456265211105347 + 17.83744239807129 + 17.908225297927856) / 3,
    (15.063777685165405 + 15.174835681915283 + 15.834700345993042) / 3,
    (14.946574687957764 + 14.801498889923096 + 15.058035373687744) / 3,
    (15.12024998664856 + 15.121056318283081 + 15.138529777526855) / 3,
    (16.46402406692505 + 15.827002763748169 + 15.526332139968872) / 3,
    (14.137307405471802 + 14.37822151184082 + 14.282505750656128) / 3,
    (13.947516918182373 + 14.01244568824768 + 14.07427167892456) / 3,
    (14.206322193145752 + 14.062494993209839 + 14.10977840423584) / 3,
    (14.859481573104858 + 14.930624723434448 + 14.359340190887451) / 3,
    (13.99988579750061 + 13.91719651222229 + 13.987231492996216) / 3,
    (13.838573694229126 + 13.699345111846924 + 13.7616286277771) / 3,
    (13.909495830535889 + 13.928926944732666 + 13.809917211532593) / 3,
    (14.423280000686646 + 14.391132593154907 + 14.265496969223022) / 3
]

# Organize data by reducer count for the second graph
reducer_data_2 = {}
for i in range(len(mapper_counts_2)):
    reducer = reducer_counts_2[i]
    if reducer not in reducer_data_2:
        reducer_data_2[reducer] = {'mappers': [], 'times': []}
    reducer_data_2[reducer]['mappers'].append(mapper_counts_2[i])
    reducer_data_2[reducer]['times'].append(times_2[i])  # Use times_2 directly

# Plot the second graph
plt.figure(figsize=(10, 6))
colors = ['b', 'g', 'r', 'c']  # Different colors for each reducer count
for i, (reducer, data) in enumerate(reducer_data_2.items()):
    plt.plot(data['mappers'], data['times'], marker='o', color=colors[i], label=f'Reducers: {reducer}')

plt.xlabel('Mapper Count')
plt.ylabel('Average Time (seconds)')
plt.title('Average Time vs Mapper Count for Different Reducer Counts (Graph 2)')
plt.legend()
plt.grid(True)
plt.xticks([2, 4, 8, 16])  # Ensure x-ticks match mapper counts
plt.savefig('average_time_vs_mapper_count_graph_2.png')
plt.show()

# %%
# Data for the second graph
reducer_counts_3 = [2, 2, 2, 2, 4, 4, 4, 4, 8, 8, 8, 8, 16, 16, 16, 16]
mapper_counts_3 = [2, 4, 8, 16, 2, 4, 8, 16, 2, 4, 8, 16, 2, 4, 8, 16]

# Mini data set
times_3 = [
    (1.8767948150634766 + 1.593893 + 1.785336) / 3,
    (1.7477083206176758 + 1.630558 + 1.848462) / 3,
    (1.7477281093597412 + 1.778961 + 2.038635) / 3,
    (1.9929068088531494 + 1.818474 + 1.814264) / 3,

    (1.5299577713012695 + 1.408601 + 1.927794) / 3,
    (1.4617059230804443 + 1.555192 + 1.676371) / 3,
    (1.9690642356872559 + 1.644996 + 1.584598) / 3,
    (1.9054303169250488 + 1.855281 + 1.973843) / 3,

    (1.5284056663513184 + 1.539074 + 1.605022) / 3,
    (1.5084116458892822 + 1.847514 + 1.602924) / 3,
    (1.6651406288146973 + 1.719370 + 1.711915) / 3,
    (1.8344223499298096 + 1.954503 + 2.076168) / 3,

    (1.754826307296753 + 1.698853 + 1.537221) / 3,
    (2.030583381652832 + 1.744495 + 1.843498) / 3,
    (1.7606165409088135 + 1.699769 + 1.774320) / 3,
    (1.9661269187927246 + 1.905649 + 2.054124) / 3
]

# Organize data by reducer count for the second graph
reducer_data_3 = {}
for i in range(len(mapper_counts_3)):
    reducer = reducer_counts_3[i]
    if reducer not in reducer_data_3:
        reducer_data_3[reducer] = {'mappers': [], 'times': []}
    reducer_data_3[reducer]['mappers'].append(mapper_counts_2[i])
    reducer_data_3[reducer]['times'].append(times_3[i])  # Use times_3 directly

# Plot the second graph
plt.figure(figsize=(10, 6))
colors = ['b', 'g', 'r', 'c']  # Different colors for each reducer count
for i, (reducer, data) in enumerate(reducer_data_3.items()):
    plt.plot(data['mappers'], data['times'], marker='o', color=colors[i], label=f'Reducers: {reducer}')

plt.xlabel('Mapper Count')
plt.ylabel('Average Time (seconds)')
plt.title('Average Time vs Mapper Count for Different Reducer Counts (Graph 2)')
plt.legend()
plt.grid(True)
plt.xticks([2, 4, 8, 16])  # Ensure x-ticks match mapper counts
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the mapper and reducer counts
mapper_counts = [2, 4, 8, 16]
reducer_counts = [2, 4, 8, 16]

# Store the data in a dictionary for clarity
data = { # Average times for large configuration
    "2M-2R": {"mapper_time": (19.891771+20.124084+19.763099)/3, "reducer_time": (4.017670+3.960406+3.985936)/3},
    "2M-4R": {"mapper_time": (19.985984+19.956462+19.966260)/3, "reducer_time": (1.971571+1.941826+1.932585)/3},
    "2M-8R": {"mapper_time": (20.044816+20.261541+19.832134)/3, "reducer_time": (1.000864+0.994081+0.980486)/3},
    "2M-16R": {"mapper_time": (19.740630+19.867812+19.754256)/3, "reducer_time": (0.446464+0.509075+0.496829)/3},
    "4M-2R": {"mapper_time": (11.416766+10.449848+10.466516)/3, "reducer_time": (3.941438+3.937239+3.961860)/3},
    "4M-4R": {"mapper_time": (10.393491+10.929698+10.498038)/3, "reducer_time": (1.985157+2.004671+1.966019)/3},
    "4M-8R": {"mapper_time": (10.311926+10.493264+10.497253)/3, "reducer_time": (0.977370+0.990301+1.041963)/3},
    "4M-16R": {"mapper_time": (10.263156+10.281799+10.572764)/3, "reducer_time": (0.436246+0.473635+0.448261)/3},
    "8M-2R": {"mapper_time": (5.774683+5.923570+5.861336)/3, "reducer_time": (3.949373+3.967026+4.052001)/3},
    "8M-4R": {"mapper_time": (5.718321+5.882276+5.733588)/3, "reducer_time": (2.001972+2.012852+1.973642)/3},
    "8M-8R": {"mapper_time": (5.811986+5.876065+5.828149)/3, "reducer_time": (1.036612+1.101381+0.930550)/3},
    "8M-16R": {"mapper_time": (5.543163+5.930433+6.165477)/3, "reducer_time": (0.529637+0.543581+0.484790)/3},
    "16M-2R": {"mapper_time": (2.736667+3.017234+2.759864)/3, "reducer_time": (3.964814+3.905501+3.993193)/3},
    "16M-4R": {"mapper_time": (2.928868+3.121966+2.837127)/3, "reducer_time": (2.046033+2.097726+1.964221)/3},
    "16M-8R": {"mapper_time": (2.925101+3.034788+3.076027)/3, "reducer_time": (1.144434+1.087566+1.036312)/3},
    "16M-16R": {"mapper_time": (2.711314+3.006506+3.300860)/3, "reducer_time": (0.548050+0.616807+0.547402)/3},
}

# Add total_time as the sum of mapper_time and reducer_time
for config in data:
    data[config]["total_time"] = data[config]["mapper_time"] + data[config]["reducer_time"]

# Convert the dictionary into lists for plotting
labels = list(data.keys())
mapper_times = [data[config]["mapper_time"] for config in labels]
reducer_times = [data[config]["reducer_time"] for config in labels]
total_times = [data[config]["total_time"] for config in labels]

# Combine all data into a list of tuples for sorting
combined_data = list(zip(labels, mapper_times, reducer_times, total_times))

# Sort the data by total time (from quickest to slowest)
combined_data.sort(key=lambda x: x[3])

# Unpack the sorted data
sorted_labels, sorted_mapper_times, sorted_reducer_times, sorted_total_times = zip(*combined_data)

# Create a grouped bar chart
x = np.arange(len(sorted_labels))  # x-axis positions for the groups
width = 0.2  # Width of each bar

plt.figure(figsize=(16, 8))

# Plot mapper time, reducer time, and total time as grouped bars
bars_mapper = plt.bar(x, sorted_mapper_times, width, label='Mapper Time', color='lightgreen', edgecolor='black')
bars_reducer = plt.bar(x + width, sorted_reducer_times, width, label='Reducer Time', color='salmon', edgecolor='black')
bars_total = plt.bar(x + 2 * width, sorted_total_times, width, label='Total Time', color='skyblue', edgecolor='black')

# Add labels, title, and custom x-axis tick labels
plt.xlabel('Mapper-Reducer Configuration')
plt.ylabel('Average Time (seconds)')
plt.title('MapReduce Performance Analysis (Sorted by Total Time)')
plt.xticks(x + width, sorted_labels, rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Add value labels on top of each bar
for bars in [bars_mapper, bars_reducer, bars_total]:
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom', fontsize=8)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import json

# Load the results from the three JSON files
file_paths = ['resultsS1N1.json', 'resultsS2N1.json', 'resultsS3N1.json']
all_results = []

for file_path in file_paths:
    with open(file_path, 'r') as json_file:
        results = json.load(json_file)
        all_results.extend(results)

# Convert the results into a dictionary for averaging
data = {}
for result in all_results:
    key = f"{result['mappers']}M-{result['reducers']}R"
    if key not in data:
        data[key] = {
            "total_time": [],
            "mapper_time": [],
            "reducer_time": []
        }
    data[key]["total_time"].append(result["total_time"])
    data[key]["mapper_time"].append(result["mapper_time"])
    data[key]["reducer_time"].append(result["reducer_time"])

# Compute the average times for each configuration
averaged_data = {}
for key, times in data.items():
    averaged_data[key] = {
        "total_time": sum(times["total_time"]) / len(times["total_time"]),
        "mapper_time": sum(times["mapper_time"]) / len(times["mapper_time"]),
        "reducer_time": sum(times["reducer_time"]) / len(times["reducer_time"])
    }

# Convert the dictionary into lists for plotting
labels = list(averaged_data.keys())
mapper_times = [averaged_data[config]["mapper_time"] for config in labels]
reducer_times = [averaged_data[config]["reducer_time"] for config in labels]
total_times = [averaged_data[config]["total_time"] for config in labels]

# Combine all data into a list of tuples for sorting
combined_data = list(zip(labels, mapper_times, reducer_times, total_times))

# Sort the data by total time (from quickest to slowest)
combined_data.sort(key=lambda x: x[3])

# Unpack the sorted data
sorted_labels, sorted_mapper_times, sorted_reducer_times, sorted_total_times = zip(*combined_data)

# Create a grouped bar chart
x = np.arange(len(sorted_labels))  # x-axis positions for the groups
width = 0.2  # Width of each bar

plt.figure(figsize=(16, 8))

# Plot mapper time, reducer time, and total time as grouped bars
bars_mapper = plt.bar(x, sorted_mapper_times, width, label='Mapper Time', color='lightgreen', edgecolor='black')
bars_reducer = plt.bar(x + width, sorted_reducer_times, width, label='Reducer Time', color='salmon', edgecolor='black')
bars_total = plt.bar(x + 2 * width, sorted_total_times, width, label='Total Time', color='skyblue', edgecolor='black')

# Add labels, title, and custom x-axis tick labels
plt.xlabel('Mapper-Reducer Configuration')
plt.ylabel('Average Time (seconds)')
plt.title('MapReduce Performance Analysis on a small dataset (Sorted by Total Time)')
plt.xticks(x + width, sorted_labels, rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Add value labels on top of each bar
for bars in [bars_mapper, bars_reducer, bars_total]:
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom', fontsize=8)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter  # Import FuncFormatter for custom y-axis labels

# Example data for single node and cluster (10 nodes)
data_single_node = {
    "2M-2R": {"total_time": 71.50268244743347},
    "2M-4R": {"total_time": 69.83384203910828},
    "2M-8R": {"total_time": 70.15922832489014},
    "2M-16R": {"total_time": 71.56477308273315},
    "4M-2R": {"total_time": 67.62529802322388},
    "4M-4R": {"total_time": 63.91146731376648},
    "4M-8R": {"total_time": 60.930219888687134},
    "4M-16R": {"total_time": 67.33778190612793},
    "8M-2R": {"total_time": 57.470606327056885},
    "8M-4R": {"total_time": 56.27682614326477},
    "8M-8R": {"total_time": 56.10840344429016},
    "8M-16R": {"total_time": 55.99714469909668},
    "16M-2R": {"total_time": 55.72042202949524},
    "16M-4R": {"total_time": 54.927385091781616},
    "16M-8R": {"total_time": 52.56553030014038},
    "16M-16R": {"total_time": 55.122700452804565},
}

data_cluster = {
    "2M-2R": {"total_time": 35.0},
    "2M-4R": {"total_time": 34.0},
    "2M-8R": {"total_time": 33.0},
    "2M-16R": {"total_time": 36.0},
    "4M-2R": {"total_time": 32.0},
    "4M-4R": {"total_time": 30.0},
    "4M-8R": {"total_time": 29.0},
    "4M-16R": {"total_time": 31.0},
    "8M-2R": {"total_time": 28.0},
    "8M-4R": {"total_time": 27.0},
    "8M-8R": {"total_time": 26.0},
    "8M-16R": {"total_time": 27.5},
    "16M-2R": {"total_time": 26.0},
    "16M-4R": {"total_time": 25.0},
    "16M-8R": {"total_time": 24.0},
    "16M-16R": {"total_time": 25.5},
}

# Calculate the difference in time for each configuration
# Difference = Cluster Time - Single Node Time
differences = {
    config: data_cluster[config]["total_time"] - data_single_node[config]["total_time"]
    for config in data_single_node
}

# Sort the differences from largest to smallest (most negative to least negative)
sorted_differences = dict(sorted(differences.items(), key=lambda x: x[1]))

# Convert the sorted differences into lists for plotting
labels = list(sorted_differences.keys())
diff_times = list(sorted_differences.values())

# Create a bar chart
x = np.arange(len(labels))  # x-axis positions for the groups
width = 0.8  # Width of each bar

plt.figure(figsize=(16, 8))

# Plot the differences
bars = plt.bar(x, diff_times, width, color='skyblue', edgecolor='black')

# Add labels, title, and custom x-axis tick labels
plt.xlabel('Mapper-Reducer Configuration')
plt.ylabel('Time Difference (Cluster - Single Node) (seconds)')
plt.title('Time Difference Between Cluster (10 Nodes) and Single Node')
plt.xticks(x, labels, rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Invert the y-axis so 0 is at the top and time goes into negative as it moves down
# plt.gca().invert_yaxis()

# Add minus sign to y-axis labels
def format_y_axis(value, _):
    return f'{value:.1f}' if value >= 0 else f'{value:.1f}'  # Add minus sign for negative values

plt.gca().yaxis.set_major_formatter(FuncFormatter(format_y_axis))

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom', fontsize=8)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter  # Import FuncFormatter for custom y-axis labels
import json

# Load the results from the three JSON files for single node and cluster
single_node_files = ['resultsL1N1.json', 'resultsL2N1.json', 'resultsL3N1.json']
cluster_files = ['resultsL1N10.json', 'resultsL2N10.json', 'resultsL3N10.json']

def load_and_average_results(file_paths):
    all_results = []
    for file_path in file_paths:
        with open(file_path, 'r') as json_file:
            results = json.load(json_file)
            all_results.extend(results)

    # Convert the results into a dictionary for averaging
    data = {}
    for result in all_results:
        key = f"{result['mappers']}M-{result['reducers']}R"
        if key not in data:
            data[key] = {
                "total_time": [],
                "mapper_time": [],
                "reducer_time": []
            }
        data[key]["total_time"].append(result["total_time"])
        data[key]["mapper_time"].append(result["mapper_time"])
        data[key]["reducer_time"].append(result["reducer_time"])

    # Compute the average times for each configuration
    averaged_data = {}
    for key, times in data.items():
        averaged_data[key] = {
            "total_time": sum(times["total_time"]) / len(times["total_time"]),
            "mapper_time": sum(times["mapper_time"]) / len(times["mapper_time"]),
            "reducer_time": sum(times["reducer_time"]) / len(times["reducer_time"])
        }

    return averaged_data

# Load and average the results for single node and cluster
data_single_node = load_and_average_results(single_node_files)
data_cluster = load_and_average_results(cluster_files)

# Calculate the difference in time for each configuration
# Difference = Cluster Time - Single Node Time
differences = {
    config: data_cluster[config]["total_time"] - data_single_node[config]["total_time"]
    for config in data_single_node
}

# Sort the differences from largest to smallest (most negative to least negative)
sorted_differences = dict(sorted(differences.items(), key=lambda x: x[1]))

# Convert the sorted differences into lists for plotting
labels = list(sorted_differences.keys())
diff_times = list(sorted_differences.values())

# Create a bar chart
x = np.arange(len(labels))  # x-axis positions for the groups
width = 0.8  # Width of each bar

plt.figure(figsize=(16, 8))

# Plot the differences
bars = plt.bar(x, diff_times, width, color='skyblue', edgecolor='black')

# Add labels, title, and custom x-axis tick labels
plt.xlabel('Mapper-Reducer Configuration')
plt.ylabel('Time Difference (Cluster - Single Node) (seconds)')
plt.title('Time Difference Between Cluster (10 Nodes) and Single Node')
plt.xticks(x, labels, rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Add minus sign to y-axis labels
def format_y_axis(value, _):
    return f'{value:.1f}' if value >= 0 else f'{value:.1f}'  # Add minus sign for negative values

plt.gca().yaxis.set_major_formatter(FuncFormatter(format_y_axis))

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom', fontsize=8)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

# Show the plot
plt.show()
